# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Part-A- E-Commerce

# %% [markdown]
# #### i. Dashboard-E-com-1

# %%
plt.figure(figsize=(20,8))
E_com_1=plt.imread('Dashboard-E-com-1.jpg')
plt.imshow(E_com_1)

# %%
#### ii. Dashboard-E-com-2

# %%
plt.figure(figsize=(20,10))
E_com_2=plt.imread('Dashboard-E-com-2.jpg')
plt.imshow(E_com_2)

# %%
#### iii. Dashboard-E-com-3

# %%
plt.figure(figsize=(20,10))
E_com_3=plt.imread('Dashboard-E-com-3.jpg')
plt.imshow(E_com_1)

# %%
#### iv. Dashboard-E-com-4

# %%
plt.figure(figsize=(20,8))
E_com_1=plt.imread('Dashboard-E-com-1.jpg')
plt.imshow(E_com_1)

# %%
#### v. Dashboard-E-com-5

# %%
plt.figure(figsize=(20,8))
E_com_1=plt.imread('Dashboard-E-com-1.jpg')
plt.imshow(E_com_1)

# %%
#### vi. Dashboard-E-com-6

# %%
plt.figure(figsize=(20,8))
E_com_1=plt.imread('Dashboard-E-com-1.jpg')
plt.imshow(E_com_1)
